# %% [markdown]
# D'après Hachette TSTI2D 2020 p 28

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="bg-info">
#
# <b> Exécuter le programme ci-dessous afin d'obtenir le graphique I = f(t) du docment précédent.
# <div>Pour exécuter la cellule faire Schift+entrée

# %%
import numpy as np

import matplotlib.pyplot as plt

I = [0,5,5,16,16,5,5,0]

t = [0,5,25,30,80,85,105,110]

U = 7.4

# pour fixer la taille de la figure largeur puis hauteur 

figure = plt.figure(figsize = (15, 7)) 


# affichage de la l'intensité I(t) (bleu)

plt.plot(t,I,"bo-")

plt.ylabel('Intensité en Ampère', color="blue")
plt.xlabel('Temps en seconde', color="blue")
plt.grid()

# %% [markdown]
# <div class="bg-danger">
#
# <b> 1.	Exprimer la puissance électrique P délivrée par la batterie en fonction de la tension nominale U(supposée constante) et de l'intensité I du courant électrique.Compléter le programme ci-dessous(**************), en s'aidant du doc. 2,permettant de tracer la représentation graphique P = f(t).

# %%
P=[]
for i in range(len(I)):
    
    P.append(********) #  info : la notation I[i] permet de récupérer les valeurs de I du programme précédent


# affichage de la la Puissance P(t) en Rouge
figure = plt.figure(figsize = (15, 7)) 
plt.plot(t,P,"ro-")

plt.ylabel('Puissance en Watt', color="red")
plt.xlabel('Temps en seconde', color="red")
plt.grid()

# %% [markdown]
# <div class="bg-danger">
#
# <b>
# 2.	Retrouver la valeur de 5,92 kJ de l'énergie électrique délivrée par la batterie pendant la phase de vol stationnaire.
# <div>3.	Montrer que le calcul précédent de l'énergie revient à déterminer l'aire sous la courbe P = f[t).
# <div>4.	Calculer alors les autres énergies électriques et compléter le tableau du doc. 2.
# <div>5. Exécuter le programme ci-dessous et vérifier le calcul effectué à la question 4.
# <div>Quelle méthode est uilisée par le programmepour calculer l'énergie ?

# %%
# affichage de la puissance P(t) + rectangles en vert
figure = plt.figure(figsize = (15, 7)) 

plt.plot(t,P,"r--")

plt.xlabel('temps en seconde')

plt.ylabel('Puissance en watt', color="red")

plt.grid()



integrale = 0

for i in range(7):

   integrale = integrale + P[i]*(t[i+1]-t[i])

    # dessin du rectangle

   t_rect = [t[i], t[i], t[i+1], t[i+1]] # abscisses des sommets
   
   p_rect = [0   , P[i], P[i]  , 0      ] # ordonnees des sommets

   plt.plot(t_rect, p_rect,"g")

print("Energie =", round(integrale), "J")

# %% [markdown]
# <div class="bg-danger">
#
# <b>
# Conclusion :
# Vérifier que la phase de test n'a consommé que 15 % de l'énergie stockée dans la batterie.
